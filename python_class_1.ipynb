# %%
course='data science'
print(course)
# Out:
# data science

# %%
print(course[5:])
# Out:
# science

# %%
print(course[5:])
print(course[-12:-8])
# Out:
# science
# data

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"

# %% [markdown]
# Write the indexing expression to print "Edukron".

# %%
print(text[0:7])
# Out:
# Edukron

# %% [markdown]
# Write the indexing expression to print "Data" (first occurrence).

# %%
print(text[8:12])
# Out:
# Data

# %% [markdown]
# Write the indexing expression to print "Science".

# %%
text.index('Science')
# Out:
# 13

# %%
type(2j)
# Out:
# complex

# %%
a=1+2j
a.real
# Out:
# 1.0

# %%
a=2+3j
a.imag
# Out:
# 3.0

# %%
x="data engineering"
l = len(x)
print(l)
a= x[1:4] #acess certain values
a
b = x[1] #acess via index
b
c = x[-3:-1]
c
# Out:
# 16
# 'in'
